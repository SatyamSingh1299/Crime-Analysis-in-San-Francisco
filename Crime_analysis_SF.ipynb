# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("incident_reports_SF_.csv")
df.head()
# Out:
#   Incident Datetime Incident Date Incident Time  Incident Year  \
# 0  25-07-2021 00:00    25-07-2021         00:00           2021
# 1  28-06-2022 23:58    28-06-2022         23:58           2022
# 2  11-03-2022 10:30    11-03-2022         10:30           2022
# 3  15-05-2021 17:47    15-05-2021         17:47           2021
# 4  28-06-2022 17:22    28-06-2022         17:22           2022
#
#   Incident Day of Week   Report Datetime        Row ID  Incident ID  \
# 0               Sunday  25-07-2021 13:41  1.060000e+11      1057189
# 1              Tuesday  28-06-2022 23:58  1.170000e+11      1165543
# 2               Friday  11-03-2022 20:03  1.130000e+11      1130480
# 3             Saturday  15-05-2021 17:47  1.030000e+11      1030518
# 4              Tuesday  28-06-2022 17:22  1.170000e+11      1165351
#
#    Incident Number  CAD Number  ... Longitude Point  Neighborhoods  \
# 0        216105573         NaN  ...       NaN   NaN            NaN
# ...

# %%
df.columns
# Out:
# Index(['Incident Datetime', 'Incident Date', 'Incident Time', 'Incident Year',
#        'Incident Day of Week', 'Report Datetime', 'Row ID', 'Incident ID',
#        'Incident Number', 'CAD Number', 'Report Type Code',
#        'Report Type Description', 'Filed Online', 'Incident Code',
#        'Incident Category', 'Incident Subcategory', 'Incident Description',
#        'Resolution', 'Intersection', 'CNN', 'Police District',
#        'Analysis Neighborhood', 'Supervisor District', 'Latitude', 'Longitude',
#        'Point', 'Neighborhoods', 'ESNCAG - Boundary File',
#        'Central Market/Tenderloin Boundary Polygon - Updated',
#        'Civic Center Harm Reduction Project Boundary',
#        'HSOC Zones as of 2018-06-05', 'Invest In Neighborhoods (IIN) Areas',
#        'Current Supervisor Districts', 'Current Police Districts'],
#       dtype='object')

# %%
print(df.shape)
df.info()
# Out:
# (651578, 34)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651578 entries, 0 to 651577
# Data columns (total 34 columns):
#  #   Column                                                Non-Null Count   Dtype
# ---  ------                                                --------------   -----
#  0   Incident Datetime                                     651578 non-null  object
#  1   Incident Date                                         651578 non-null  object
#  2   Incident Time                                         651578 non-null  object
#  3   Incident Year                                         651578 non-null  int64
#  4   Incident Day of Week                                  651578 non-null  object
#  5   Report Datetime                                       651578 non-null  object
#  6   Row ID                                                651578 non-null  float64
#  7   Incident ID                                           651578 non-null  int64
# ...

# %%
df = df[['Incident Date','Incident Time','Incident Year','Incident Day of Week','Filed Online', 'Incident Category','Resolution',
        'Police District','Analysis Neighborhood','Supervisor District','Latitude','Longitude']]
df
# Out:
#        Incident Date Incident Time  Incident Year Incident Day of Week  \
# 0         25-07-2021         00:00           2021               Sunday
# 1         28-06-2022         23:58           2022              Tuesday
# 2         11-03-2022         10:30           2022               Friday
# 3         15-05-2021         17:47           2021             Saturday
# 4         28-06-2022         17:22           2022              Tuesday
# ...              ...           ...            ...                  ...
# 651573    18-10-2022         17:00           2022              Tuesday
# 651574    17-10-2022         19:00           2022               Monday
# 651575    10-06-2022         17:00           2022               Friday
# 651576    18-10-2022         13:30           2022              Tuesday
# 651577    18-10-2022         17:30           2022              Tuesday
#
#         Filed Online    Incident Category      Resolution Police District  \
# ...

# %%
df.head()
# Out:
#   Incident Date Incident Time  Incident Year Incident Day of Week  \
# 0    25-07-2021         00:00           2021               Sunday
# 1    28-06-2022         23:58           2022              Tuesday
# 2    11-03-2022         10:30           2022               Friday
# 3    15-05-2021         17:47           2021             Saturday
# 4    28-06-2022         17:22           2022              Tuesday
#
#    Filed Online  Incident Category      Resolution Police District  \
# 0          True      Larceny Theft  Open or Active        Southern
# 1         False     Other Offenses  Open or Active       Out of SF
# 2          True      Lost Property  Open or Active         Central
# 3         False  Recovered Vehicle  Open or Active       Out of SF
# 4         False  Recovered Vehicle  Open or Active       Out of SF
#
#   Analysis Neighborhood  Supervisor District  Latitude  Longitude
# 0                   NaN                  NaN       NaN        NaN
# ...

# %%
df.shape
# Out:
# (651578, 12)

# %%
df.describe()
# Out:
#        Incident Year  Supervisor District       Latitude      Longitude
# count  651578.000000        617150.000000  617150.000000  617150.000000
# mean     2019.821162             5.965318      37.769268    -122.423960
# std         1.403058             2.806142       0.024406       0.026375
# min      2018.000000             1.000000      37.707988    -122.511295
# 25%      2019.000000             3.000000      37.755029    -122.434483
# 50%      2020.000000             6.000000      37.775834    -122.417716
# 75%      2021.000000             8.000000      37.785882    -122.407305
# max      2022.000000            11.000000      37.829991    -122.363743

# %%
df.isnull().sum()
# Out:
# Incident Date                0
# Incident Time                0
# Incident Year                0
# Incident Day of Week         0
# Filed Online                 0
# Incident Category          555
# Resolution                   0
# Police District              0
# Analysis Neighborhood    34553
# Supervisor District      34428
# Latitude                 34428
# Longitude                34428
# dtype: int64

# %% [markdown]
# df.count()

# %%
percent = ((df.isnull().sum()/df.count())*100).sort_values()
print(percent)
# Out:
# Incident Date            0.000000
# Incident Time            0.000000
# Incident Year            0.000000
# Incident Day of Week     0.000000
# Filed Online             0.000000
# Resolution               0.000000
# Police District          0.000000
# Incident Category        0.085250
# Supervisor District      5.578547
# Latitude                 5.578547
# Longitude                5.578547
# Analysis Neighborhood    5.599935
# dtype: float64

# %% [markdown]
# We can see that only 5% of data is missing in 4 columns out of 12 columns.
# Hence we will ignore it.

# %%
df.tail()
# Out:
#        Incident Date Incident Time  Incident Year Incident Day of Week  \
# 651573    18-10-2022         17:00           2022              Tuesday
# 651574    17-10-2022         19:00           2022               Monday
# 651575    10-06-2022         17:00           2022               Friday
# 651576    18-10-2022         13:30           2022              Tuesday
# 651577    18-10-2022         17:30           2022              Tuesday
#
#         Filed Online    Incident Category      Resolution Police District  \
# 651573         False        Larceny Theft  Open or Active            Park
# 651574         False   Malicious Mischief  Open or Active         Central
# 651575         False                Fraud  Open or Active         Taraval
# 651576         False  Motor Vehicle Theft  Open or Active         Central
# 651577         False       Suspicious Occ  Open or Active        Northern
#
#                  Analysis Neighborhood  Supervisor District   Latitude  \
# ...

# %%
#Univariate
#will check each variable and see its distribution
df.columns
# Out:
# Index(['Incident Date', 'Incident Time', 'Incident Year',
#        'Incident Day of Week', 'Filed Online', 'Incident Category',
#        'Resolution', 'Police District', 'Analysis Neighborhood',
#        'Supervisor District', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df['Incident Time'].describe()
# Out:
# count     651578
# unique      1440
# top        00:00
# freq       18936
# Name: Incident Time, dtype: object

# %%
df.head()
# Out:
#   Incident Date Incident Time  Incident Year Incident Day of Week  \
# 0    25-07-2021         00:00           2021               Sunday
# 1    28-06-2022         23:58           2022              Tuesday
# 2    11-03-2022         10:30           2022               Friday
# 3    15-05-2021         17:47           2021             Saturday
# 4    28-06-2022         17:22           2022              Tuesday
#
#    Filed Online  Incident Category      Resolution Police District  \
# 0          True      Larceny Theft  Open or Active        Southern
# 1         False     Other Offenses  Open or Active       Out of SF
# 2          True      Lost Property  Open or Active         Central
# 3         False  Recovered Vehicle  Open or Active       Out of SF
# 4         False  Recovered Vehicle  Open or Active       Out of SF
#
#   Analysis Neighborhood  Supervisor District  Latitude  Longitude
# 0                   NaN                  NaN       NaN        NaN
# ...

# %%
scary_time = df['Incident Time'].value_counts().sort_values(ascending=False)[:10]
scary_time
# Out:
# 00:00    18936
# 12:00    17735
# 18:00    13758
# 17:00    12650
# 20:00    12353
# 19:00    12046
# 15:00    10623
# 21:00    10500
# 16:00    10454
# 22:00    10316
# Name: Incident Time, dtype: int64

# %%
plt.subplots()
plt.bar(scary_time.index,scary_time)
plt.xticks(rotation =45)
plt.title("Most Common Attack Time")
plt.ylabel('No of Attacks')
plt.xlabel('Time (24hr)')
sns.set_style('whitegrid')
sns.set_palette('viridis')

# %%
#incident Year
df['Incident Year'].value_counts()
# Out:
# 2018    152555
# 2019    148209
# 2021    128498
# 2020    118169
# 2022    104147
# Name: Incident Year, dtype: int64

# %%
sns.barplot(df['Incident Year'].value_counts().index,df['Incident Year'].value_counts())
sns.set_style('whitegrid')
plt.title('Year-wise No of Incidents')
plt.xlabel("Year")
plt.ylabel("No of Incidents")
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'No of Incidents')

# %%
#IncidentDay
day = df['Incident Day of Week'].value_counts()
day
# Out:
# Friday       99725
# Wednesday    96422
# Thursday     92777
# Monday       92556
# Saturday     92139
# Tuesday      91968
# Sunday       85991
# Name: Incident Day of Week, dtype: int64

# %%
sns.barplot(df['Incident Day of Week'].value_counts().index,df['Incident Day of Week'].value_counts())
plt.xlabel("Week Day")
plt.ylabel("Count of cases")
plt.title('Most Attacked Weekday')
sns.set_style('whitegrid')
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Incident Filed online or Offline
df['Filed Online'].value_counts()
# Out:
# False    520488
# True     131090
# Name: Filed Online, dtype: int64

# %%
sns.barplot(df['Filed Online'].value_counts().index,df['Filed Online'].value_counts())
plt.xlabel('Filed Online')
plt.ylabel('No of cases')
plt.title('Incident Reported Online')
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Incident Reported Online')

# %%
#Incident Category
incidents = df['Incident Category'].value_counts()[0:15]
incidents
# Out:
# Larceny Theft          198256
# Other Miscellaneous     46032
# Malicious Mischief      44230
# Assault                 39551
# Non-Criminal            39134
# Burglary                36779
# Motor Vehicle Theft     32638
# Recovered Vehicle       24936
# Fraud                   20426
# Warrant                 19245
# Lost Property           19243
# Drug Offense            15627
# Robbery                 14644
# Missing Person          14166
# Suspicious Occ          13402
# Name: Incident Category, dtype: int64

# %%
sns.barplot(y = incidents.index[:15],x = incidents[:15])
plt.title('Top 15 Most Frequently Commited Crime ')
plt.xlabel("Total No of Occurences")
plt.ylabel("Category")
# Out:
# Text(0, 0.5, 'Category')

# %%
#Resolution
df['Resolution'].value_counts()
# Out:
# Open or Active          519986
# Cite or Arrest Adult    126280
# Unfounded                 3622
# Exceptional Adult         1690
# Name: Resolution, dtype: int64

# %%
sns.barplot(df['Resolution'].value_counts().index,df['Resolution'].value_counts())
plt.xlabel('Resolution')
plt.ylabel('Count')
plt.title('Case Status')
sns.set_style('whitegrid')
sns.set_palette('RdBu')
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Police District
df['Police District'].value_counts()
# Out:
# Central       97219
# Northern      88492
# Mission       82211
# Southern      78958
# Tenderloin    62372
# Bayview       57582
# Ingleside     48982
# Taraval       45709
# Richmond      40631
# Park          30366
# Out of SF     19056
# Name: Police District, dtype: int64

# %%
sns.barplot(df['Police District'].value_counts().index,df['Police District'].value_counts())
plt.xticks(rotation =45)
plt.xlabel('Police District')
plt.ylabel('No of cases')
plt.title('District wise Attacks')
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'District wise Attacks')

# %%
#Analysis Neighborhood
df['Analysis Neighborhood'].value_counts()
# Out:
# Mission                           66175
# Tenderloin                        63338
# Financial District/South Beach    51025
# South of Market                   50130
# Bayview Hunters Point             40407
# North Beach                       20595
# Western Addition                  19886
# Castro/Upper Market               18625
# Sunset/Parkside                   18497
# Nob Hill                          17828
# Marina                            17552
# Hayes Valley                      16871
# Russian Hill                      14986
# Outer Richmond                    14288
# West of Twin Peaks                12490
# Chinatown                         11561
# Bernal Heights                    11515
# Mission Bay                       11208
# Pacific Heights                   11040
# Potrero Hill                      10604
# Excelsior                         10471
# Haight Ashbury                    10379
# Outer Mission                      8890
# ...

# %%
sns.barplot( y = df['Analysis Neighborhood'].value_counts().index[:20],x = df['Analysis Neighborhood'].value_counts()[:20])
#plt.xticks(rotation = 90)
plt.title('Top 20 Attacked Neighbourhoods')
# Out:
# Text(0.5, 1.0, 'Top 20 Attacked Neighbourhoods')

# %%
#supervisor District
df['Supervisor District'].value_counts()
# Out:
# 6.0     144140
# 3.0      91284
# 10.0     67494
# 5.0      62976
# 9.0      60818
# 2.0      47326
# 8.0      47064
# 1.0      29409
# 7.0      26174
# 11.0     22853
# 4.0      17612
# Name: Supervisor District, dtype: int64

# %%
sns.barplot(df['Supervisor District'].value_counts().index,df['Supervisor District'].value_counts())
plt.xlabel('Supervisor District Number')
plt.ylabel('No of Cases')
plt.title('Supervisor District Wise Cases')
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Supervisor District Wise Cases')

# %%
df.head()
# Out:
#   Incident Date Incident Time  Incident Year Incident Day of Week  \
# 0    25-07-2021         00:00           2021               Sunday
# 1    28-06-2022         23:58           2022              Tuesday
# 2    11-03-2022         10:30           2022               Friday
# 3    15-05-2021         17:47           2021             Saturday
# 4    28-06-2022         17:22           2022              Tuesday
#
#    Filed Online  Incident Category      Resolution Police District  \
# 0          True      Larceny Theft  Open or Active        Southern
# 1         False     Other Offenses  Open or Active       Out of SF
# 2          True      Lost Property  Open or Active         Central
# 3         False  Recovered Vehicle  Open or Active       Out of SF
# 4         False  Recovered Vehicle  Open or Active       Out of SF
#
#   Analysis Neighborhood  Supervisor District  Latitude  Longitude
# 0                   NaN                  NaN       NaN        NaN
# ...

# %%
theft_day = df[df['Incident Category']=='Larceny Theft']['Incident Day of Week']
sns.barplot(theft_day.value_counts().index,theft_day.value_counts())
plt.xlabel('Day of Week')
plt.ylabel('No of Cases')
plt.title('Most Common Day for Theft')
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most Common Day for Theft')

# %%
theft_day = df[df['Incident Category']=='Larceny Theft']['Analysis Neighborhood']
sns.barplot(theft_day.value_counts()[:15].index,theft_day.value_counts()[:15])
plt.xlabel('Neighborhood')
plt.ylabel('No of Cases')
plt.xticks(rotation =90)
plt.title('Most Common Neighborhood for Theft')
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most Common Neighborhood for Theft')

# %%
mission_attacks = df[df['Analysis Neighborhood']=='Mission']['Incident Category']
sns.barplot(mission_attacks.value_counts()[:15].index,mission_attacks.value_counts()[:15])
plt.xlabel('Neighborhood')
plt.xticks(rotation = 90)
plt.ylabel('No of Cases')
plt.title('Most Common Attacks in "Mission"')
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most Common Attacks in "Mission"')

# %% [markdown]
# The most common Attack type in "Mission" neighborhood is Theft, and as seen before "Mission" had the most number of Attacks compared all the other neighborhood.

# %%
central_attacks = df[df['Police District']=='Central']['Incident Category']
sns.barplot(central_attacks.value_counts()[:15].index,central_attacks.value_counts()[:15])
plt.xticks(rotation= 90)
plt.xlabel('Attack Type')
plt.ylabel('No of Cases')
plt.title('Most Attack Types in Central Police District')
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most Attack Types in Central Police District')

# %% [markdown]
# The Police District 'Central' was the most attacked district as seen before and now we can observe that theft is the leading attack type in this district.

# %%
year_attacks = df[df['Incident Year']==2018]['Incident Category']
year_attacks.value_counts()[:15].plot(kind='bar')
plt.xlabel('Attack Type')
plt.ylabel('No of Cases')
plt.title('Most Attack Types in year 2018')
# Out:
# Text(0.5, 1.0, 'Most Attack Types in year 2018')

# %%
year_attacks = df[df['Incident Year']==2019]['Incident Category']
year_attacks.value_counts()[:15].plot(kind='bar')
plt.xlabel('Attack Type')
plt.ylabel('No of Cases')
plt.title('Most Attack Types in year 2019')
# Out:
# Text(0.5, 1.0, 'Most Attack Types in year 2019')

# %%
year_attacks = df[df['Incident Year']==2020]['Incident Category']
year_attacks.value_counts()[:15].plot(kind='bar')
plt.xlabel('Attack Type')
plt.ylabel('No of Cases')
plt.title('Most Attack Types in year 2020')
# Out:
# Text(0.5, 1.0, 'Most Attack Types in year 2020')

# %%
year_attacks = df[df['Incident Year']==2021]['Incident Category']
year_attacks.value_counts()[:15].plot(kind='bar')
plt.xlabel('Attack Type')
plt.ylabel('No of Cases')
plt.title('Most Attack Types in year 2021')
# Out:
# Text(0.5, 1.0, 'Most Attack Types in year 2021')

# %%
year_attacks = df[df['Incident Year']==2022]['Incident Category']
year_attacks.value_counts()[:15].plot(kind='bar')
plt.xlabel('Attack Type')
plt.ylabel('No of Cases')
plt.title('Most Attack Types in year 2022')
# Out:
# Text(0.5, 1.0, 'Most Attack Types in year 2022')

# %% [markdown]
# We can see that, Theft has been leading the charts for all 4 years, with malicious mischief coming up to 2nd in 2021, otherwise burgalary and theft have been the top most common Attacks since 2018. This information can be useful to the government as they can then work on to eradicate theft by focussing on preventive measures.

# %%
day_attacks = df[df['Incident Year']==2018]['Incident Day of Week']
print(day_attacks.value_counts())
sns.barplot(day_attacks.value_counts()[:15].index,day_attacks.value_counts()[:15])
sns.set_palette('RdBu_r')
sns.set_style('darkgrid')
plt.xlabel('Weekday')
plt.ylabel('No of Cases')
plt.title('Most Attacked Day in year 2018')
# Out:
# Friday       23236
# Wednesday    22359
# Saturday     22049
# Monday       21730
# Thursday     21594
# Tuesday      21557
# Sunday       20030
# Name: Incident Day of Week, dtype: int64
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most Attacked Day in year 2018')

# %%
day_attacks = df[df['Incident Year']==2019]['Incident Day of Week']
print(day_attacks.value_counts())
sns.barplot(day_attacks.value_counts()[:15].index,day_attacks.value_counts()[:15])
#sns.set_palette('RdBu_r')
#sns.set_style('darkgrid')
plt.xlabel('Weekday')
plt.ylabel('No of Cases')
plt.title('Most Attacked Day in year 2019')
# Out:
# Friday       22660
# Wednesday    22062
# Monday       21217
# Tuesday      21217
# Saturday     20848
# Thursday     20671
# Sunday       19534
# Name: Incident Day of Week, dtype: int64
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most Attacked Day in year 2019')

# %%
day_attacks = df[df['Incident Year']==2020]['Incident Day of Week']
print(day_attacks.value_counts())
sns.barplot(day_attacks.value_counts()[:15].index,day_attacks.value_counts()[:15])
#sns.set_palette('RdBu_r')
#sns.set_style('darkgrid')
plt.xlabel('Weekday')
plt.ylabel('No of Cases')
plt.title('Most Attacked Day in year 2020')
# Out:
# Friday       17651
# Wednesday    17585
# Thursday     17030
# Monday       16725
# Tuesday      16702
# Saturday     16659
# Sunday       15817
# Name: Incident Day of Week, dtype: int64
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most Attacked Day in year 2020')

# %%
day_attacks = df[df['Incident Year']==2021]['Incident Day of Week']
print(day_attacks.value_counts())
sns.barplot(day_attacks.value_counts()[:15].index,day_attacks.value_counts()[:15])
#sns.set_palette('RdBu_r')
#sns.set_style('darkgrid')
plt.xlabel('Weekday')
plt.ylabel('No of Cases')
plt.title('Most Attacked Day in year 2021')
# Out:
# Friday       20245
# Wednesday    18977
# Thursday     18491
# Monday       18465
# Tuesday      17997
# Saturday     17669
# Sunday       16654
# Name: Incident Day of Week, dtype: int64
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most Attacked Day in year 2021')

# %%
day_attacks = df[df['Incident Year']==2022]['Incident Day of Week']
print(day_attacks.value_counts())
sns.barplot(day_attacks.value_counts()[:15].index,day_attacks.value_counts()[:15])
#sns.set_palette('RdBu_r')
#sns.set_style('darkgrid')
plt.xlabel('Weekday')
plt.ylabel('No of Cases')
plt.title('Most Attacked Day in year 2022')
# Out:
# Friday       15933
# Wednesday    15439
# Thursday     14991
# Saturday     14914
# Tuesday      14495
# Monday       14419
# Sunday       13956
# Name: Incident Day of Week, dtype: int64
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most Attacked Day in year 2022')

# %% [markdown]
# We can clearly see that straight for 4 years , "Friday" and "Wednesday" have been the most attacked day.
# Citizens and Police officials can be warned to be extra careful on these days as its the same for 4 years consecutively.

# %%
df.head()
# Out:
#   Incident Date Incident Time  Incident Year Incident Day of Week  \
# 0    25-07-2021         00:00           2021               Sunday
# 1    28-06-2022         23:58           2022              Tuesday
# 2    11-03-2022         10:30           2022               Friday
# 3    15-05-2021         17:47           2021             Saturday
# 4    28-06-2022         17:22           2022              Tuesday
#
#    Filed Online  Incident Category      Resolution Police District  \
# 0          True      Larceny Theft  Open or Active        Southern
# 1         False     Other Offenses  Open or Active       Out of SF
# 2          True      Lost Property  Open or Active         Central
# 3         False  Recovered Vehicle  Open or Active       Out of SF
# 4         False  Recovered Vehicle  Open or Active       Out of SF
#
#   Analysis Neighborhood  Supervisor District  Latitude  Longitude
# 0                   NaN                  NaN       NaN        NaN
# ...

# %%
time_attacks = df[df['Incident Time']>'20:00']['Incident Category']
sns.barplot(time_attacks.value_counts()[:15].index,time_attacks.value_counts()[:15])
plt.xlabel('Attack Type')
plt.ylabel('No of cases')
plt.xticks(rotation =90)
plt.title('Most common Attacks types after 8:00 PM')
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most common Attacks types after 8:00 PM')

# %% [markdown]
# After 8:00 PM , Theft as usual is the most common type of attack

# %%
fire_day = df[df['Incident Category']=='Fire Report']['Incident Day of Week']
print(fire_day.value_counts())
sns.barplot(fire_day.value_counts().index,fire_day.value_counts())
plt.xlabel('Day of Week')
plt.ylabel('No of Cases')
plt.title('Most Fire Reports')
# Out:
# Wednesday    150
# Monday       141
# Saturday     138
# Thursday     127
# Sunday       124
# Friday       124
# Tuesday      118
# Name: Incident Day of Week, dtype: int64
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most Fire Reports')

# %%
fire_day = df[df['Incident Year'] == 2021]['Incident Day of Week']
print(fire_day.value_counts())
sns.barplot(fire_day.value_counts().index,fire_day.value_counts())
plt.xlabel('Day of Week')
plt.ylabel('No of Cases')
plt.title('Most common day of attack 2021 ')
# Out:
# Friday       20245
# Wednesday    18977
# Thursday     18491
# Monday       18465
# Tuesday      17997
# Saturday     17669
# Sunday       16654
# Name: Incident Day of Week, dtype: int64
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most common day of attack 2021 ')

# %% [markdown]
# Most of the fire reports are filed on Wednesday.

# %%
fire_day = df[df['Incident Category']=='Missing Person']['Incident Day of Week']
print(fire_day.value_counts())
sns.barplot(fire_day.value_counts().index,fire_day.value_counts())
plt.xlabel('Day of Week')
plt.ylabel('No of Cases')
plt.title('Missing Person')
# Out:
# Tuesday      2197
# Friday       2179
# Monday       2146
# Thursday     2034
# Wednesday    1994
# Saturday     1869
# Sunday       1747
# Name: Incident Day of Week, dtype: int64
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Missing Person')

# %% [markdown]
# Most cases for missing persons are filed on a Tuesday.

# %%
day_attacks = df[df['Incident Year']==2018]['Police District']
print(day_attacks.value_counts())
sns.barplot(day_attacks.value_counts()[:15].index,day_attacks.value_counts()[:15])
#sns.set_palette('RdBu_r')
#sns.set_style('darkgrid')
plt.xticks(rotation = 90)
plt.xlabel('Weekday')
plt.ylabel('No of Cases')
plt.title('Most Attacked Police District in year 2018')
# Out:
# Central       24413
# Mission       21238
# Southern      20196
# Northern      19103
# Tenderloin    15230
# Bayview       11942
# Ingleside     10685
# Taraval       10250
# Richmond       8396
# Park           7192
# Out of SF      3910
# Name: Police District, dtype: int64
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most Attacked Police District in year 2018')

# %%
day_attacks = df[df['Incident Year']==2019]['Police District']
print(day_attacks.value_counts())
sns.barplot(day_attacks.value_counts()[:15].index,day_attacks.value_counts()[:15])
#sns.set_palette('RdBu_r')
#sns.set_style('darkgrid')
plt.xticks(rotation = 90)
plt.xlabel('Weekday')
plt.ylabel('No of Cases')
plt.title('Most Attacked Police District in year 2019')
# Out:
# Central       23414
# Northern      20914
# Mission       19004
# Southern      17795
# Tenderloin    14409
# Bayview       11991
# Ingleside     10249
# Taraval       10065
# Richmond       9289
# Park           6975
# Out of SF      4104
# Name: Police District, dtype: int64
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most Attacked Police District in year 2019')

# %%
day_attacks = df[df['Incident Year']==2020]['Police District']
print(day_attacks.value_counts())
sns.barplot(day_attacks.value_counts()[:15].index,day_attacks.value_counts()[:15])
#sns.set_palette('RdBu_r')
#sns.set_style('darkgrid')
plt.xticks(rotation = 90)
plt.xlabel('Weekday')
plt.ylabel('No of Cases')
plt.title('Most Attacked Police District in year 2020')
# Out:
# Northern      16844
# Mission       14448
# Central       14409
# Southern      13676
# Bayview       11630
# Tenderloin    10812
# Ingleside     10289
# Taraval        8531
# Richmond       7892
# Park           6089
# Out of SF      3549
# Name: Police District, dtype: int64
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most Attacked Police District in year 2020')

# %%
open_df = df[df['Resolution']=="Open or Active"]['Incident Category']
#print(open_df.value_counts())
sns.barplot(y = open_df.value_counts()[:10].index,x = open_df.value_counts()[:10])
plt.ylabel('Incident Type')
plt.xlabel('No of Cases')
plt.title('Unsolved cases by Crime Category')
# Out:
# Text(0.5, 1.0, 'Unsolved cases by Crime Category')

# %%
day_attacks = df[df['Incident Year']==2021]['Police District']
print(day_attacks.value_counts())
sns.barplot(day_attacks.value_counts()[:15].index,day_attacks.value_counts()[:15])
#sns.set_palette('RdBu_r')
#sns.set_style('darkgrid')
plt.xticks(rotation = 90)
plt.xlabel('Weekday')
plt.ylabel('No of Cases')
plt.title('Most Attacked Police District in year 2021')
# Out:
# Central       19540
# Northern      17371
# Mission       15280
# Southern      14726
# Bayview       12545
# Tenderloin    11192
# Ingleside     10180
# Taraval        9154
# Richmond       8600
# Park           5908
# Out of SF      4002
# Name: Police District, dtype: int64
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most Attacked Police District in year 2021')

# %%
day_attacks = df[df['Incident Year']==2022]['Police District']
print(day_attacks.value_counts())
sns.barplot(day_attacks.value_counts()[:15].index,day_attacks.value_counts()[:15])
#sns.set_palette('RdBu_r')
#sns.set_style('darkgrid')
plt.xticks(rotation = 90)
plt.xlabel('Weekday')
plt.ylabel('No of Cases')
plt.title('Most Attacked Police District in year 2022')
# Out:
# Central       15443
# Northern      14260
# Southern      12565
# Mission       12241
# Tenderloin    10729
# Bayview        9474
# Taraval        7709
# Ingleside      7579
# Richmond       6454
# Park           4202
# Out of SF      3491
# Name: Police District, dtype: int64
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most Attacked Police District in year 2022')

# %% [markdown]
# All 4 years have different police districts with most number of cases,but mainly "Central", "Northern", "Mission" and "Southern were seen in the top 4.

# %%
pd.crosstab(df['Incident Year'],df['Police District']).plot(kind='bar',figsize=(14,10))
plt.title('District wise Incidents per year ')
plt.ylabel("Number of Attacks")
# Out:
# Text(0, 0.5, 'Number of Attacks')

# %%
pd.crosstab(df['Incident Year'],df['Police District']).plot(kind='line')
plt.title('Incident Activity by Year')
plt.ylabel("Number of Attacks")
plt.grid()

# %%
pd.crosstab(df['Incident Year'],df['Incident Category']=='Fire Report').plot(kind='line')
plt.title('Incident Activity by Year')
plt.ylabel("Number of Attacks")
plt.grid()

# %%
pd.crosstab(df['Incident Year'],df['Incident Category']=='Larceny theft').plot(kind='line')
plt.title('Incident Activity by Year')
plt.ylabel("Number of Attacks")
plt.grid()
